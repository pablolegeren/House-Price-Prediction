# %%
# !pip install pycaret

# %%
pip install catboost

# %%
pip install optuna

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsRegressor
import scipy.stats
from sklearn.preprocessing import StandardScaler
from pycaret.regression import setup, compare_models
from sklearn.model_selection import KFold, cross_val_score

from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

import optuna

# %%
train0 = pd.read_csv('train.csv')
test0 = pd.read_csv('test.csv')

# %%
target = train0['SalePrice']
test_ids = test0['Id']

train1 = train0.drop(['Id', 'SalePrice'], axis=1)
test1 = test0.drop('Id', axis=1)

data1 = pd.concat([train1, test1], axis=0).reset_index(drop=True)
data1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RL         64.0    10475   Pave   NaN      IR1
# 1             90       RL          NaN    18890   Pave   NaN      IR1
# 2             80       RL          NaN    21453   Pave   NaN      IR1
# 3             20       RL         60.0     9600   Pave   NaN      Reg
# 4             30       RM         60.0     8967   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2925          60       RL          NaN    14364   Pave   NaN      IR1
# 2926          50       RM         50.0     6125   Pave   NaN      Reg
# 2927          20       RL          NaN     8246   Pave   NaN      IR1
# 2928          20       RL         75.0    10650   Pave   NaN      Reg
# 2929          30       RL         94.0     9259   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2            Low    AllPub   CulDSac  ...           0        0    NaN    NaN
# 3            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 4            Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 2925         Low    AllPub    Inside  ...         154        0    NaN    NaN
# 2926         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2927         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 2928         Lvl    AllPub    Corner  ...           0        0    NaN  MnPrv
# 2929         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0       2    2010        WD         Normal
# 1           Gar2    8300       8    2007        WD         Normal
# 2            NaN       0      10    2006        WD         Normal
# 3            NaN       0       2    2010        WD         Normal
# 4            NaN       0      11    2007        WD        Abnorml
# ...          ...     ...     ...     ...       ...            ...
# 2925         NaN       0       4    2007        WD         Normal
# 2926         NaN       0       3    2007       CWD         Normal
# 2927         NaN       0       5    2010        WD         Normal
# 2928         NaN       0       2    2010        WD         Normal
# 2929         NaN       0       6    2010        WD         Normal
#
# [2930 rows x 79 columns]

# %%
data2 = data1.copy()

# %%
data2['MSSubClass'] = data2['MSSubClass'].astype(str)

# %% [markdown]
# En el caso de las variables cualitativas donde haya valores nulos existen dos posibilidades: una ha sido rellenar los nulos con la palabra "None" y otra ha sido rellenarlos con la moda.
#
# Lo que se hace es rellenar estos valores nulos con "None". Por ejemplo, si hay un nulo en la columna "PoolQC" significa que no hay piscina por tanto se imputa un "None". En estos casos, se entiende el valor de "NA" como un nulo pero realmente es el verdadero valor que tiene la variable.
#
# Para otras columnas se ha decicido rellenar los valores nulos con la moda de cada una de las columnas, es decir, por el valor más frecuente.

# %%
# Impute using a constant value
for column in [
    'Alley',
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'FireplaceQu',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
    'PoolQC',
    'Fence',
    'MiscFeature'
]:
    data2[column] = data2[column].fillna("None")

# Impute using the column mode
for column in [
    'MSZoning',
    'Utilities',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Electrical',
    'KitchenQual',
    'Functional',
    'SaleType'
]:
    data2[column] = data2[column].fillna(data2[column].mode()[0])

# %%
data3 = data2.copy()

# %% [markdown]
# En el caso de las variables numéricas se ha optado, debido que sobre lo que se está trabajando son casa y suelen compartir características, por rellenar los valores nulos con valores de observaciones cercanas mediante el algortimo de KNN, es decir, con las casas más parecidas.

# %%
def knn_impute(df, na_target):
    df = df.copy()

    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[: ,numeric_df.isna().sum() == 0].columns

    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]

    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)

    y_pred = knn.predict(X_test)

    df.loc[df[na_target].isna() == True, na_target] = y_pred

    return df

# %%
for column in [
    'LotFrontage',
    'MasVnrArea',
    'BsmtFinSF1',
    'BsmtFinSF2',
    'BsmtUnfSF',
    'TotalBsmtSF',
    'BsmtFullBath',
    'BsmtHalfBath',
    'GarageYrBlt',
    'GarageCars',
    'GarageArea'
]:
    data3 = knn_impute(data3, column)

# %%
data4 = data3.copy()

# %% [markdown]
# Se ha decidido crear algunas variables nuevas que puedan aportar información al modelo como combinación de otras, mediante sumas y multiplicaciones

# %%
data4["SqFtPerRoom"] = data4["GrLivArea"] / (data4["TotRmsAbvGrd"] + data4["FullBath"] + data4["HalfBath"] + data4["KitchenAbvGr"])

data4['Total_Home_Quality'] = data4['OverallQual'] + data4['OverallCond']

data4['Total_Bathrooms'] = (data4['FullBath'] + (0.5 * data4['HalfBath']) + data4['BsmtFullBath'] + (0.5 * data4['BsmtHalfBath']))

data4["HighQualSF"] = data4["1stFlrSF"] + data4["2ndFlrSF"]

# %%
data5 = data4.copy()

# %% [markdown]
# Para las variables numéricas, se comprueba si alguna de ellas está sesgada (skewed) y en ese caso se el aplica la función logarítmica para corregir esa distribución.

# %%
skew_df = pd.DataFrame(data5.select_dtypes(np.number).columns, columns=['Feature'])
skew_df['Skew'] = skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data5[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew'].apply(lambda x: True if x >= 0.5 else False)
skew_df
# Out:
#                Feature       Skew  Absolute Skew  Skewed
# 0          LotFrontage   1.333981       1.333981    True
# 1              LotArea  12.770448      12.770448    True
# 2          OverallQual   0.191520       0.191520   False
# 3          OverallCond   0.561348       0.561348    True
# 4            YearBuilt  -0.598164       0.598164    True
# 5         YearRemodAdd  -0.445806       0.445806   False
# 6           MasVnrArea   2.600227       2.600227    True
# 7           BsmtFinSF1   1.425643       1.425643    True
# 8           BsmtFinSF2   4.129423       4.129423    True
# 9            BsmtUnfSF   0.918231       0.918231    True
# 10         TotalBsmtSF   1.156966       1.156966    True
# 11            1stFlrSF   1.464171       1.464171    True
# 12            2ndFlrSF   0.862903       0.862903    True
# 13        LowQualFinSF  12.111957      12.111957    True
# 14           GrLivArea   1.265175       1.265175    True
# 15        BsmtFullBath   0.624391       0.624391    True
# 16        BsmtHalfBath   3.925970       3.925970    True
# 17            FullBath   0.172684       0.172684   False
# 18            HalfBath   0.701328       0.701328    True
# 19        BedroomAbvGr   0.322441       0.322441   False
# 20        KitchenAbvGr   4.275373       4.275373    True
# 21        TotRmsAbvGrd   0.763869       0.763869    True
# 22          Fireplaces   0.733702       0.733702    True
# 23         GarageYrBlt  -0.345791       0.345791   False
# 24          GarageCars  -0.218582       0.218582   False
# 25          GarageArea   0.251072       0.251072   False
# 26          WoodDeckSF   1.844575       1.844575    True
# 27         OpenPorchSF   2.571951       2.571951    True
# 28       EnclosedPorch   3.996383       3.996383    True
# 29           3SsnPorch  11.288382      11.288382    True
# 30         ScreenPorch   3.940877       3.940877    True
# 31            PoolArea  16.930469      16.930469    True
# 32             MiscVal  20.735295      20.735295    True
# 33              MoSold   0.192760       0.192760   False
# 34              YrSold   0.132084       0.132084   False
# 35         SqFtPerRoom   0.892674       0.892674    True
# 36  Total_Home_Quality  -0.555269       0.555269    True
# 37     Total_Bathrooms   0.491535       0.491535   False
# 38          HighQualSF   1.248051       1.248051    True

# %%
for column in skew_df.query("Skewed == True")['Feature'].values:
    data5[column] = np.log1p(data5[column])

# %% [markdown]
# Para los números de mes lo que se decide hacer es convertirlos en una función coseno ya que los meses de un año es algo cíclico, es decir, empiezan siempre en 1 y terminan en 12. De esta forma podemos conseguir que la distancia entre el mes 12 y el 1 sea la misma que entre el 11 y el 12, o entre el 1 y el 2.
#
# Para conseguir el valor de "0.5326" lo que se ha hecho ha sido en la web de Geogebra probar cuál es el número "X" que permitía que el valor de cos(X) fuese -1, y se ha considerado poner el "-" delante simulando que el valor de la función coseno fuese la temperatura, de esta forma conseguimos que la "temperatura" en el mes 6 valiese 1 (calor) y que en el mes 12 fuese -1 (frío).

# %%
data5['MoSold'] = (-np.cos(0.5236 * data5['MoSold']))

# %%
data6 = data5.copy()

# %%
data6 = pd.get_dummies(data6)

# %%
data7 = data6.copy()

# %%
scaler = StandardScaler()
scaler.fit(data7)

data7 = pd.DataFrame(scaler.transform(data7), index=data7.index, columns=data7.columns)

# %%
data8 = data7.copy()

# %%
train_final = data8.loc[:train0.index.max(), :].copy()
test_final = data8.loc[train0.index.max() + 1:, :].reset_index(drop=True).copy()

# %%
setup(data=pd.concat([train_final, target], axis = 1), target='SalePrice')
# Out:
# <style type="text/css">
# #T_07173_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_07173" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07173_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_07173_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07173_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07173_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_07173_row0_col1" class="data row0 col1" >2943</td>
#     </tr>
#     <tr>
#       <th id="T_07173_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07173_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_07173_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_07173_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07173_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_07173_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_07173_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07173_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_07173_row3_col1" class="data row3 col1" >(2302, 321)</td>
#     </tr>
#     <tr>
#       <th id="T_07173_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07173_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_07173_row4_col1" class="data row4 col1" >(2302, 321)</td>
#     </tr>
#     <tr>
#       <th id="T_07173_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07173_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_07173_row5_col1" class="data row5 col1" >(1611, 321)</td>
#     </tr>
#     <tr>
#       <th id="T_07173_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T
, #T_8b5b2_row12_col3, #T_8b5b2_row12_col4, #T_8b5b2_row12_col5, #T_8b5b2_row12_col6, #T_8b5b2_row13_col0, #T_8b5b2_row13_col1, #T_8b5b2_row13_col2, #T_8b5b2_row13_col3, #T_8b5b2_row13_col4, #T_8b5b2_row13_col5, #T_8b5b2_row13_col6, #T_8b5b2_row14_col0, #T_8b5b2_row14_col1, #T_8b5b2_row14_col2, #T_8b5b2_row14_col3, #T_8b5b2_row14_col4, #T_8b5b2_row14_col5, #T_8b5b2_row14_col6, #T_8b5b2_row15_col0, #T_8b5b2_row15_col1, #T_8b5b2_row15_col2, #T_8b5b2_row15_col3, #T_8b5b2_row15_col4, #T_8b5b2_row15_col5, #T_8b5b2_row15_col6, #T_8b5b2_row16_col0, #T_8b5b2_row16_col1, #T_8b5b2_row16_col2, #T_8b5b2_row16_col3, #T_8b5b2_row16_col4, #T_8b5b2_row16_col5, #T_8b5b2_row16_col6, #T_8b5b2_row17_col0, #T_8b5b2_row17_col1, #T_8b5b2_row17_col2, #T_8b5b2_row17_col3, #T_8b5b2_row17_col4, #T_8b5b2_row17_col5, #T_8b5b2_row17_col6, #T_8b5b2_row18_col0, #T_8b5b2_row18_col1, #T_8b5b2_row18_col2, #T_8b5b2_row18_col3, #T_8b5b2_row18_col4, #T_8b5b2_row18_col5, #T_8b5b2_row18_col6 {
#   text-align: left;
# }
# #T_8b5b2_row0_col1, #T_8b5b2_row0_col2, #T_8b5b2_row0_col3, #T_8b5b2_row0_col4, #T_8b5b2_row0_col5, #T_8b5b2_row7_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8b5b2_row0_col7, #T_8b5b2_row1_col7, #T_8b5b2_row2_col7, #T_8b5b2_row3_col7, #T_8b5b2_row4_col7, #T_8b5b2_row5_col7, #T_8b5b2_row6_col7, #T_8b5b2_row7_col7, #T_8b5b2_row8_col7, #T_8b5b2_row9_col7, #T_8b5b2_row10_col7, #T_8b5b2_row11_col7, #T_8b5b2_row12_col7, #T_8b5b2_row13_col7, #T_8b5b2_row14_col7, #T_8b5b2_row15_col7, #T_8b5b2_row16_col7, #T_8b5b2_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8b5b2_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8b5b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b5b2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8b5b2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8b5b2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8b5b2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8b5b2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8b5b2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8b5b2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8b5b2_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b5b2_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_8b5b2_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_8b5b2_row0_col1" class="data row0 col1" >21964.5091</td>
#       <td id="T_8b5b2_row0_col2" class="data row0 col2" >1180087901.0940</td>
#       <td id="T_8b5b2_row0_col3" class="data row0 col3" >33875.0560</td>
#       <td id="T_8b5b2_row0_col4" class="data row0 col4" >0.7992</td>
#       <td id="T_8b5b2_row0_col5" class="data row0 col5" >0.1932</td>
#       <td id="T_8b5b2_row0_col6" class="data row0 col6" >0.1857</td>
#       <td id="T_8b5b2_row0_col7" class="data row0 col7" >8.5340</td>
#     </tr>
#     <tr>
#       <th id="T_8b5b2_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_8b5b2_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8b5b2_row1_col1" class="data row1 col1" >23215.6990</td>
#       <td id="T_8b5b2_row1_col2" class="data row1 col2" >1290328572.6504</td>
#       <td id="T_8b5b2_row1_col3" class="data row1 col3" >35621.7323</td>
#       <td id="T_8b5b2_row1_col4" class="data row1 col4" >0.7809</td>
#       <td id="T_8b5b2_row1_col5" class="data row1 col5" >0.2034</td>
#       <td id="T_8b5b2_row1_col6" class="data row1 col6" >0.1982</td>
#       <td id="T_8b5b2_row1_col7" class="data row1 col7" >2.7900</td>
#     </tr>
#     <tr>
#       <th id="T_8b5b2_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_8b5b2_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8b5b2_row2_col1" class="data row2 col1" >22845.0869</td>
#       <td id="T_8b5b2_row2_col2" class="data row2 col2" >1275404924.7545</td>
#       <td id="T_8b5b2_row2_col3" class="data row2 col3" >35293.0810</td>
#       <td id="T_8b5b2_row2_col4" class="data row2 col4" >0.7806</td>
#       <td id="T_8b5b2_row2_col5" class="data row2 col5" >0.2036</td>
#       <td id="T_8b5b2_row2_col6" class="data row2 col6" >0.1964</td>
#       <td id="T_8b5b2_row2_col7" class="data row2 col7" >1.3350</td>
#     </tr>
#     <tr>
#       <th id="T_8b5b2_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_8b5b2_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_8b5b2_row3_col1" class="data row3 col1" >23605.1639</td>
#       <td id="T_8b5b2_row3_col2" class="data row3 col2" >1309213714.8808</td>
#       <td id="T_8b5b2_row3_col3" class="data row3 col3" >35820.5615</td>
#       <td id="T_8b5b2_row3_col4" class="data row3 col4" >0.7764</td>
#       <td id="T_8b5b2_row3_col5" class="data row3 col5" >0.2076</td>
#       <td id="T_8b5b2_row3_col6" class="data row3 col6" >0.1984</td>
#       <td id="T_8b5b2_row3_col7" class="data row3 col7" >4.6670</td>
#     </tr>
#     <tr>
#       <th id="T_8b5b2_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_8b5b2_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_8b5b2_row4_col1" class="data row4 col1" >23116.7594</td>
#       <td id="T_8b5b2_row4_col2" class="data row4 col2" >1357359974.4000</td>
#       <td id="T_8b5b2_row4_col3" class="data row4 col3" >36354.3926</td>
#       <td id="T_8b5b2_row4_col4" class="data row4 col4" >0.7720</td>
#       <td id="T_8b5b2_row4_col5" class="data row4 col5" >0.2042</td>
#       <td id="T_8b5b2_row4_col6" class="data row4 col6" >0.1819</td>
#       <td id="T_8b5b2_row4_col7" class="data row4 col7" >0.3410</td>
#     </tr>
#     <tr>
#       <th id="T_8b5b2_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_8b5b2_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_8b5b2_row5_col1" class="data row5 col1" >23544.8461</td>
#       <td id="T_8b5b2_row5_col2" class="data row5 col2" >1427139552.0000</td>
#       <td id="T_8b5b2_row5_col3" class="data row5 col3" >37284.5273</td>
#       <td id="T_8b5b2_row5_col4" class="data row5 c
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# Se escoge el modelo con el mejor rendimiento, es decir, el modelo con un menor valor de RMSE: CatBoost Regressor.
#
# Se podrían haber cogido más modelos y probar cuál es el que finalmente ofrece mejores resultados, se ha decidido solo probar con el CatBoost

# %%
modelos = {
    "catboost":CatBoostRegressor(verbose=0)
}

# %%
for name, model in modelos.items():
    model.fit(train_final, target)
    print(name + " trained.")
# Out:
# catboost trained.

# %%
from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK

# %% [markdown]
# Se construyen los Grids donde más adelante cada uno de los modelos iterará hasta encontrar la mejor combinación de hiperparámetros.

# %%
catboost_params = {
    'iterations': hp.randint('iterations',100,1000),
    'learning_rate': hp.uniform('learning_rate', 0.1, 0.5),
    'depth': hp.randint('depth',4,10),
    'l2_leaf_reg': hp.randint('l2_leaf_reg',1,10),
    'eval_metric':'RMSE',
    'early_stopping_rounds': 200,
    'random_seed': 42
}

# %%
models = {
    "catboost": CatBoostRegressor(**catboost_params, verbose=0)
}

# %%
SAMPLE_RATE = 0.4
RANDOM_SEED = 1
EARLY_STOPPING_ROUND = 100

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_final, target, test_size=0.2, random_state=RANDOM_SEED)

# %%
X_train, X_eval, y_train, y_eval = train_test_split(X_train, y_train, test_size=0.1, random_state=RANDOM_SEED)

# %%
def objective(trial):
    param = {}
    param['learning_rate'] = trial.suggest_discrete_uniform("learning_rate", 0.001, 0.02, 0.001)
    param['depth'] = trial.suggest_int('depth', 9, 15)
    param['l2_leaf_reg'] = trial.suggest_discrete_uniform('l2_leaf_reg', 1.0, 5.5, 0.5)
    param['min_child_samples'] = trial.suggest_categorical('min_child_samples', [1, 4, 8, 16, 32])
    param['grow_policy'] = 'Depthwise'
    param['iterations'] = 10000
    param['use_best_model'] = True
    param['eval_metric'] = 'RMSE'
    param['od_type'] = 'iter'
    param['od_wait'] = 20
    param['random_state'] = RANDOM_SEED
    param['logging_level'] = 'Silent'

    regressor = CatBoostRegressor(**param)

    regressor.fit(X_train.copy(), y_train.copy(),
                  eval_set=[(X_eval.copy(), y_eval.copy())],
                  early_stopping_rounds=EARLY_STOPPING_ROUND)
    loss = mean_squared_error(y_valid, regressor.predict(X_valid.copy()))
    return loss

# %%
# %%time
study = optuna.create_study(study_name=f'catboost-seed{RANDOM_SEED}')
study.optimize(objective, n_trials=100, n_jobs=-1, timeout=24000)
# Out:
# [I 2024-04-25 08:27:46,283] A new study created in memory with name: catboost-seed1
# [I 2024-04-25 08:28:31,596] Trial 1 finished with value: 1069578775.1892498 and parameters: {'learning_rate': 0.018000000000000002, 'depth': 9, 'l2_leaf_reg': 2.0, 'min_child_samples': 1}. Best is trial 1 with value: 1069578775.1892498.
# [I 2024-04-25 08:29:03,217] Trial 2 finished with value: 1061374288.1601657 and parameters: {'learning_rate': 0.006, 'depth': 10, 'l2_leaf_reg': 2.5, 'min_child_samples': 32}. Best is trial 2 with value: 1061374288.1601657.
# [I 2024-04-25 08:36:52,250] Trial 3 finished with value: 1048700588.9287137 and parameters: {'learning_rate': 0.003, 'depth': 14, 'l2_leaf_reg': 3.0, 'min_child_samples': 4}. Best is trial 3 with value: 1048700588.9287137.
# [I 2024-04-25 08:38:29,167] Trial 4 finished with value: 1077231620.9332566 and parameters: {'learning_rate': 0.008, 'depth': 13, 'l2_leaf_reg': 3.0, 'min_child_samples': 8}. Best is trial 3 with value: 1048700588.9287137.
# [I 2024-04-25 08:40:39,316] Trial 5 finished with value: 1018068036.0808485 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial
. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:19:06,985] Trial 38 finished with value: 1048827529.9051731 and parameters: {'learning_rate': 0.012, 'depth': 9, 'l2_leaf_reg': 5.0, 'min_child_samples': 8}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:21:45,478] Trial 40 finished with value: 1052817584.0257269 and parameters: {'learning_rate': 0.005, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 4}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:23:38,367] Trial 42 finished with value: 1052331594.5555122 and parameters: {'learning_rate': 0.015, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:25:46,934] Trial 43 finished with value: 1018068036.0808485 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:27:42,872] Trial 44 finished with value: 1052331594.5555122 and parameters: {'learning_rate': 0.015, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:31:05,110] Trial 45 finished with value: 1022365377.3588666 and parameters: {'learning_rate': 0.013000000000000001, 'depth': 12, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:31:25,843] Trial 41 finished with value: 1048618104.7579491 and parameters: {'learning_rate': 0.001, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 4}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:31:53,313] Trial 47 finished with value: 1088355250.9555273 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 4.5, 'min_child_samples': 16}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:39:20,912] Trial 48 finished with value: 1065667106.121702 and parameters: {'learning_rate': 0.016, 'depth': 15, 'l2_leaf_reg': 1.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:39:43,931] Trial 49 finished with value: 1072243402.1494483 and parameters: {'learning_rate': 0.013000000000000001, 'depth': 12, 'l2_leaf_reg': 5.5, 'min_child_samples': 32}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:40:07,283] Trial 46 finished with value: 1051399160.0473224 and parameters: {'learning_rate': 0.001, 'depth': 15, 'l2_leaf_reg': 4.5, 'min_child_samples': 16}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:47:59,744] Trial 50 finished with value: 1048271983.7912141 and parameters: {'learning_rate': 0.010000000000000002, 'depth': 14, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:48:15,808] Trial 51 finished with value: 1048271983.7912141 and parameters: {'learning_rate': 0.010000000000000002, 'depth': 14, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:50:13,744] Trial 52 finished with value: 1018068036.0808485 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:50:24,668] Trial 53 finished with value: 1018068036.0808485 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:51:36,746] Trial 55 finished with value: 1055550578.2768574 and parameters: {'learning_rate': 0.017, 'depth': 10, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:51:37,083] Trial 54 finished with value: 1061952786.1343716 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 10, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:53:39,038] Trial 56 finished with value: 1052331594.5555122 and parameters: {'learning_rate': 0.015, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:54:07,986] Trial 57 finished with value: 1041641250.5993965 and parameters: {'learning_rate': 0.011, 'depth': 11, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:56:09,633] Trial 58 finished with value: 1041641250.5993965 and parameters: {'learning_rate': 0.011, 'depth': 11, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:56:45,442] Trial 60 finished with value: 1041916264.4575582 and parameters: {'learning_rate': 0.012, 'depth': 10, 'l2_leaf_reg': 4.5, 'min_child_samples': 8}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:57:09,136] Trial 61 finished with value: 1069612871.3542067 and parameters: {'learning_rate': 0.013000000000000001, 'depth': 12, 'l2_leaf_reg': 5.0, 'min_child_samples': 32}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:57:17,750] Trial 59 finished with value: 1070446014.1928034 and parameters: {'learning_rate': 0.012, 'depth': 12, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 09:59:26,002] Trial 63 finished with value: 1018068036.0808485 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25
5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:24:55,653] Trial 88 finished with value: 1044998965.0589383 and parameters: {'learning_rate': 0.012, 'depth': 11, 'l2_leaf_reg': 2.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:26:01,905] Trial 89 finished with value: 1032355111.5335639 and parameters: {'learning_rate': 0.009000000000000001, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:26:40,396] Trial 90 finished with value: 1063701610.6316967 and parameters: {'learning_rate': 0.011, 'depth': 12, 'l2_leaf_reg': 5.5, 'min_child_samples': 4}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:27:25,828] Trial 91 finished with value: 1095528878.6870716 and parameters: {'learning_rate': 0.011, 'depth': 12, 'l2_leaf_reg': 2.0, 'min_child_samples': 4}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:29:25,482] Trial 92 finished with value: 1018205600.5647055 and parameters: {'learning_rate': 0.013000000000000001, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:29:44,644] Trial 93 finished with value: 1018068036.0808485 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:31:08,867] Trial 94 finished with value: 1033341073.1517448 and parameters: {'learning_rate': 0.012, 'depth': 10, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:31:24,196] Trial 95 finished with value: 1033341073.1517448 and parameters: {'learning_rate': 0.012, 'depth': 10, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:32:51,387] Trial 96 finished with value: 1033341073.1517448 and parameters: {'learning_rate': 0.012, 'depth': 10, 'l2_leaf_reg': 5.0, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:33:22,391] Trial 98 finished with value: 1060147978.0013454 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 16}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:33:46,137] Trial 97 finished with value: 1018068036.0808485 and parameters: {'learning_rate': 0.014000000000000002, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# [I 2024-04-25 10:35:07,443] Trial 99 finished with value: 1058659464.2413328 and parameters: {'learning_rate': 0.011, 'depth': 11, 'l2_leaf_reg': 5.5, 'min_child_samples': 1}. Best is trial 22 with value: 1009519989.4751137.
# CPU times: user 3h 38min 36s, sys: 5min 39s, total: 3h 44min 15s
# Wall time: 2h 7min 21s

# %%
optimized_regressor = CatBoostRegressor(learning_rate=0.012,
                                        depth=11,
                                        l2_leaf_reg=5.5,
                                        min_child_samples=1,
                                        grow_policy='Depthwise',
                                        iterations=10000,
                                        use_best_model=True,
                                        eval_metric='RMSE',
                                        od_type='iter',
                                        od_wait=20,
                                        random_state=RANDOM_SEED,
                                        logging_level='Silent')
optimized_regressor.fit(X_train.copy(), y_train.copy(),
                        eval_set=[(X_eval.copy(), y_eval.copy())],
                        early_stopping_rounds=EARLY_STOPPING_ROUND)
pred_train = optimized_regressor.predict(X_train.copy())
pred_valid = optimized_regressor.predict(X_valid.copy())

# %%
sample_sub = pd.read_csv('sample_submission.csv')

# %%
sample_sub['target'] = optimized_regressor.predict(test_final)

# %%
sample_sub = sample_sub.drop('SalePrice', axis=1)

# %%
sample_sub.rename(columns={'target': 'SalePrice'}, inplace=True)

# %%
sample_sub.set_index('ID', inplace=True)

# %%
sample_sub
# Out:
#           SalePrice
# ID
# 2303  177731.137679
# 2304  143634.795195
# 2305  411025.173892
# 2306  305680.326638
# 2307  110996.348050
# ...             ...
# 2926  254618.064020
# 2927  131220.310063
# 2928  148977.213454
# 2929  137109.251610
# 2930   96818.306572
#
# [628 rows x 1 columns]

# %%
sample_sub.to_csv('late_submission.csv')
